# %%
import rasterio as rs

# %%
base_path = 'res/smapL4-march-v1/'

# %%
paths = [base_path+'2022-03-04.tif',base_path+"2022-03-07.tif"]

# %%
from rasterio.plot import show

# %%
import os

# %%
paths = os.listdir(base_path)

# %%
i = rs.open(base_path + paths[0])

# %%
for p in paths:
    im = rs.open(base_path +p)
    print(p)
    
    show(im)
# Out:
# NASA_USDA_SMAP_SM20220305_20220307.tif
# NASA_USDA_SMAP_SM20220317_20220319.tif
# NASA_USDA_SMAP_SM20220329_20220331.tif
# NASA_USDA_SMAP_SM20220320_20220322.tif
# NASA_USDA_SMAP_SM20220302_20220304.tif
# NASA_USDA_SMAP_SM20220308_20220310.tif
# NASA_USDA_SMAP_SM20220311_20220313.tif
# NASA_USDA_SMAP_SM20220323_20220325.tif
# NASA_USDA_SMAP_SM20220326_20220328.tif
# NASA_USDA_SMAP_SM20220314_20220316.tif
